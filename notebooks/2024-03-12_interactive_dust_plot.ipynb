# %%
import pandas as pd
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d016b0f8-16fe-427d-b59e-c5634404749e" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# !head -n8 /home/jovyan/shared_data/data/aeronet/20210101_20241231_Mindelo_OSCM/20210101_20241231_Mindelo_OSCM.lev15

# %%
df = pd.read_csv(
    "/home/jovyan/shared_data/data/aeronet/20210101_20241231_Mindelo_OSCM/20210101_20241231_Mindelo_OSCM.lev15",
    skiprows=6,
)
df
# Out:
#       Date(dd:mm:yyyy) Time(hh:mm:ss)  Day_of_Year  Day_of_Year(Fraction)  \
# 0           19:04:2021       11:22:09          109             109.473715
# 1           19:04:2021       11:29:37          109             109.478900
# 2           19:04:2021       11:45:58          109             109.490255
# 3           28:06:2021       12:39:56          179             179.527731
# 4           28:06:2021       12:42:57          179             179.529826
# ...                ...            ...          ...                    ...
# 37309       06:03:2024       14:17:12           66              66.595278
# 37310       06:03:2024       14:22:12           66              66.598750
# 37311       06:03:2024       14:27:12           66              66.602222
# 37312       06:03:2024       14:37:12           66              66.609167
# 37313       06:03:2024       14:42:12           66              66.612639
#
#        AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  AOD_675nm  \
# ...

# %%
list(df.columns)
# Out:
# ['Date(dd:mm:yyyy)',
#  'Time(hh:mm:ss)',
#  'Day_of_Year',
#  'Day_of_Year(Fraction)',
#  'AOD_1640nm',
#  'AOD_1020nm',
#  'AOD_870nm',
#  'AOD_865nm',
#  'AOD_779nm',
#  'AOD_675nm',
#  'AOD_667nm',
#  'AOD_620nm',
#  'AOD_560nm',
#  'AOD_555nm',
#  'AOD_551nm',
#  'AOD_532nm',
#  'AOD_531nm',
#  'AOD_510nm',
#  'AOD_500nm',
#  'AOD_490nm',
#  'AOD_443nm',
#  'AOD_440nm',
#  'AOD_412nm',
#  'AOD_400nm',
#  'AOD_380nm',
#  'AOD_340nm',
#  'Precipitable_Water(cm)',
#  'AOD_681nm',
#  'AOD_709nm',
#  'AOD_Empty',
#  'AOD_Empty.1',
#  'AOD_Empty.2',
#  'AOD_Empty.3',
#  'AOD_Empty.4',
#  'Triplet_Variability_1640',
#  'Triplet_Variability_1020',
#  'Triplet_Variability_870',
#  'Triplet_Variability_865',
#  'Triplet_Variability_779',
#  'Triplet_Variability_675',
#  'Triplet_Variability_667',
#  'Triplet_Variability_620',
#  'Triplet_Variability_560',
#  'Triplet_Variability_555',
#  'Triplet_Variability_551',
#  'Triplet_Variability_532',
#  'Triplet_Variability_531',
# ...

# %%
df["AOD_1640nm"].where(df["AOD_1640nm"] > 0).hvplot()
# Out:
# :Curve   [index]   (AOD_1640nm)

# %%
df.iloc[36346]
# Out:
# Date(dd:mm:yyyy)                        25:01:2024
# Time(hh:mm:ss)                            17:24:17
# Day_of_Year                                     25
# Day_of_Year(Fraction)                    25.725197
# AOD_1640nm                                1.159479
#                                            ...
# Exact_Wavelengths_of_AOD(um)_Empty          -999.0
# Exact_Wavelengths_of_AOD(um)_Empty.1        -999.0
# Exact_Wavelengths_of_AOD(um)_Empty.2        -999.0
# Exact_Wavelengths_of_AOD(um)_Empty.3        -999.0
# Exact_Wavelengths_of_AOD(um)_Empty.4        -999.0
# Name: 36346, Length: 113, dtype: object
